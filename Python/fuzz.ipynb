# %%
import os
import csv
import json
import ujson
import simplejson
import orjson
import json5
import rapidjson
import ijson
from pyjson5 import loads as json5py_loads
import json_parser

#try to read file, route element. or first element. to see if it crashes, check if the exception was on purpose

# Mapping parser functions for convenience
parsers = {
    "json": json.loads,
    "ujson": ujson.loads,
    "simplejson": simplejson.loads,
    "orjson": orjson.loads,
    "json5": json5.loads,
    "rapidjson": rapidjson.loads,
    "ijson": lambda data: next(ijson.items(data, '')),
    "pyjson5": json5py_loads,
    "json_parser": json_parser.parse
}

def initialize_results_file(results_file):
    """Initializes the fuzzing results CSV file with headers."""
    with open(results_file, 'w', newline='', encoding='utf-8') as csvfile:
        result_writer = csv.writer(csvfile)
        result_writer.writerow(["File Path", "File Name", "Parser Name", "Status", "Error Message"])

def log_result(results_file, file_path, file_name, parser_name, status, error_message=""):
    """Logs the result of a parsing attempt to a CSV file."""
    with open(results_file, 'a', newline='', encoding='utf-8') as csvfile:
        result_writer = csv.writer(csvfile)
        result_writer.writerow([file_path, file_name, parser_name, status, error_message])

def fuzz_json_with_parser(parser_name, parser_func, file_path, results_file):
    """Attempts to parse a JSON file with the specified parser and logs the outcome."""
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            data = file.read()
            parser_func(data)
        # Extract file name from file path
        file_name = os.path.basename(file_path)
        log_result(results_file, file_path, file_name, parser_name, "Success")
    except Exception as e:
        file_name = os.path.basename(file_path)  # Extract file name here as well for consistency
        log_result(results_file, file_path, file_name, parser_name, "Error", str(e))

def fuzz_all_parsers(file_path, results_file):
    """Attempts to parse a JSON file with all specified parsers."""
    for parser_name, parser_func in parsers.items():
        fuzz_json_with_parser(parser_name, parser_func, file_path, results_file)

def fuzz_directory(directory_path, results_file):
    """Fuzzes all JSON files within a given directory."""
    for filename in os.listdir(directory_path):
        if filename.endswith(".json"):
            file_path = os.path.join(directory_path, filename)
            fuzz_all_parsers(file_path, results_file)

def main():
    base_directory = "C:/Users/Sammy/Documents/Thesis/AlaliSammyFuzzingJSON/JSONFiles"  # Adjust this path to your actual base directory
    results_directory = "C:/Users/Sammy/Documents/Thesis/AlaliSammyFuzzingJSON/Results"  # Adjust this path to your results directory
    results_file = os.path.join(results_directory, "fuzzing_results_python.csv")
    initialize_results_file(results_file)
    directories = [
        os.path.join(base_directory, "real_json_files")
        #os.path.join(base_directory, "mutated_json_files"),
        #os.path.join(base_directory, "generated_json_files_advanced")
    ]
    for directory in directories:
        fuzz_directory(directory, results_file)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 78
#      74         fuzz_directory(directory, results_file)
#      77 if __name__ == "__main__":
# ---> 78     main()
#
# Cell In[10], line 74, in main()
#      68 directories = [
#      69     os.path.join(base_directory, "real_json_files")
#      70     #os.path.join(base_directory, "mutated_json_files"),
#      71     #os.path.join(base_directory, "generated_json_files_advanced")
#      72 ]
#      73 for directory in directories:
# ---> 74     fuzz_directory(directory, results_file)
#
# Cell In[10], line 61, in fuzz_directory(directory_path, results_file)
#      59 if filename.endswith(".json"):
#      60     file_path = os.path.join(directory_path, filename)
# ---> 61     fuzz_all_parsers(file_path, results_file)
#
# Cell In[10], line 54, in fuzz_all_parsers(file_path, results_file)
# ...

# %%
import os
import csv
import json
import ujson
import simplejson
import orjson
import json5
import rapidjson
import ijson
from pyjson5 import loads as json5py_loads
import json_parser

#try to read file, route element. or first element. to see if it crashes, check if the exception was on purpose

# Mapping parser functions for convenience
parsers = {
    "json": json.loads,
    "ujson": ujson.loads,
    "simplejson": simplejson.loads,
    "orjson": orjson.loads,
    "json5": json5.loads,
    "rapidjson": rapidjson.loads,
    "ijson": lambda data: next(ijson.items(data, '')),
    "pyjson5": json5py_loads,
    "json_parser": json_parser.parse
}

def initialize_results_file(results_file):
    """Initializes the fuzzing results CSV file with headers."""
    with open(results_file, 'w', newline='', encoding='utf-8') as csvfile:
        result_writer = csv.writer(csvfile)
        result_writer.writerow(["File Path", "File Name", "Parser Name", "Status", "Error Message"])

def log_result(results_file, file_path, file_name, parser_name, status, error_message=""):
    """Logs the result of a parsing attempt to a CSV file."""
    with open(results_file, 'a', newline='', encoding='utf-8') as csvfile:
        result_writer = csv.writer(csvfile)
        result_writer.writerow([file_path, file_name, parser_name, status, error_message])

def fuzz_json_with_parser(parser_name, parser_func, file_path, results_file):
    """Attempts to parse a JSON file with the specified parser and logs the outcome."""
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            data = file.read()
            parsed_data = parser_func(data)
            # Automatically handle any kind of parsed data structure
            if isinstance(parsed_data, dict) and parsed_data:
                # Try to access the first available key
                first_key = next(iter(parsed_data))
                _ = parsed_data[first_key]
            elif isinstance(parsed_data, list) and parsed_data:
                # Try to access the first element of the list
                _ = parsed_data[0]
        file_name = os.path.basename(file_path)
        log_result(results_file, file_path, file_name, parser_name, "Success")
    except Exception as e:
        file_name = os.path.basename(file_path)  # Extract file name here as well for consistency
        log_result(results_file, file_path, file_name, parser_name, "Error", str(e))

def fuzz_all_parsers(file_path, results_file):
    """Attempts to parse a JSON file with all specified parsers."""
    for parser_name, parser_func in parsers.items():
        fuzz_json_with_parser(parser_name, parser_func, file_path, results_file)

def fuzz_directory(directory_path, results_file):
    """Fuzzes all JSON files within a given directory."""
    for filename in os.listdir(directory_path):
        if filename.endswith(".json"):
            file_path = os.path.join(directory_path, filename)
            fuzz_all_parsers(file_path, results_file)

def main():
    base_directory = "C:/Users/Sammy/Documents/Thesis/AlaliSammyFuzzingJSON/JSONFiles"  # Adjust this path to your actual base directory
    results_directory = "C:/Users/Sammy/Documents/Thesis/AlaliSammyFuzzingJSON/Results"  # Adjust this path to your results directory
    results_file = os.path.join(results_directory, "fuzzing_results_python.csv")
    initialize_results_file(results_file)
    directories = [
        os.path.join(base_directory, "real_json_files")
        #os.path.join(base_directory, "mutated_json_files"),
        #os.path.join(base_directory, "generated_json_files_advanced")
    ]
    for directory in directories:
        fuzz_directory(directory, results_file)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 53, in fuzz_json_with_parser(parser_name, parser_func, file_path, results_file)
#      52     file_name = os.path.basename(file_path)
# ---> 53     log_result(results_file, file_path, file_name, parser_name, "Success")
#      54 except Exception as e:
#
# Cell In[2], line 36, in log_result(results_file, file_path, file_name, parser_name, status, error_message)
#      35 """Logs the result of a parsing attempt to a CSV file."""
# ---> 36 with open(results_file, 'a', newline='', encoding='utf-8') as csvfile:
#      37     result_writer = csv.writer(csvfile)
#
# File c:\Users\Sammy\anaconda3\envs\opencv-env\lib\site-packages\IPython\core\interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
# ...
